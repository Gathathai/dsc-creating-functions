# %% [markdown]
# # Creating Functions
#
# ## Introduction
# Now that we learned about loops, it would be nice to have the ability to *reuse* our code to help us solve different problems. Functions allow us to do just that. They also give us the ability to name a sequence of operations (or block of code), thus making our code expressive. Let's see how this works, and why something like this is useful.

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# * Declare and use a basic function

# %% [markdown]
# ## Our problem so far

# %% [markdown]
# Imagine that we have a group of employees who have just joined our company.

# %%
new_employees = ['jim', 'tracy', 'lisa']
print (new_employees.title())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6d094049dd48> in <module>
#       1 new_employees = ['jim', 'tracy', 'lisa']
# ----> 2 print (new_employees.title())
#
# AttributeError: 'list' object has no attribute 'title'

# %%
new_employees = ['jim', 'tracy', 'lisa']
print([employee.title() for employee in new_employees])
# Out:
# ['Jim', 'Tracy', 'Lisa']

# %% [markdown]
# > Press shift + enter to run this code.

# %%
list_of_numbers = list(range(0,7))
list_of_numbers
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
#functions used
type()
len(0)
range()
print()
list()
.title()
#function hold a block of code
#function are stand alone but method follow instruction

# %%
list_of_names=['john','mary','esther']

# %%
list_of_names[2].title()
# Out:
# 'Esther'

# %%
for name in list_of_names:
    print(name.title())
# Out:
# John
# Mary
# Esther

# %%
#examples of method
.append() #add item at the end of collection
.upper()  #return string in upper case
.get() 
.endswith()
.startswith()
.replace()
.pop() #remove the last item in a list
.replace()
.capitalize() #make every
.extend() # add multiple items
.title() #Make the first letter cap

# %%
list_of_fruits = ['mango','apple','berry']

# %%
#create a function that will print the list of fruits
def print_fruits():
    for fruit in list_of_fruits:
        print (fruit.title())
        print_fruits()

# %%
def print_fruits(list_of_fruits):
    for fruit in list_of_fruits:
        print(fruit.title())  # Capitalize each fruit name

# Example usage
fruits = ["apple", "banana", "cherry", "date"]
print_fruits(fruits)
# Out:
# Apple
# Banana
# Cherry
# Date

# %% [markdown]
# We want to send each of them a nice welcome message.  We could use a `for` loop to create a list of `welcome_messages`.

# %%
numbers_list = list (range(0,5))
numbers_list
# Out:
# [0, 1, 2, 3, 4]

# %%
#iterate through the number list and print the elements/item
#create a function that prints number in a list

# %%
def num_list(collection):
    for num in collection:
        print(num)

# %%
def num_list(collection):  # Defines the function num_list that takes 'collection' as an argument
    for num in collection:  # Loops over each item in the collection
        print(num)  # Prints each item (num) in the collection

# Example usage
numbers = [1, 2, 3, 4, 5]  # A list of numbers
num_list(numbers)  # Calls the function with the 'numbers' list
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def num_list(i):
    for number in (i):
        print(number)

# %%
def num_list(i):
    for number in i:  # Loops through the elements of i
        print(number)  # Prints each element

# Example usage
numbers = [1, 2, 3, 4, 5]
num_list(numbers)  # Call the function with the 'numbers' list
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type (list_of_list)
len (list_of_fruits)
print (list_of_fruits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ba80773f7051> in <module>
# ----> 1 type (list_of_list)
#       2 len (list_of_fruits)
#       3 print (list_of_fruits)
#
# NameError: name 'list_of_list' is not defined

# %%
# Sample lists for demonstration
list_of_list = [[1, 2], [3, 4], [5, 6]]
list_of_fruits = ["apple", "banana", "cherry"]

# Checking the type of list_of_list
print(type(list_of_list))  # Output: <class 'list'>

# Getting the length of list_of_fruits
print(len(list_of_fruits))  # Output: 3

# Printing the contents of list_of_fruits
print(list_of_fruits)  # Output: ['apple', 'banana', 'cherry']
# Out:
# <class 'list'>
# 3
# ['apple', 'banana', 'cherry']

# %%
print_fruits()
# Out:
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# Mango
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-17-bc72b2f6079e> in <module>
# ----> 1 print_fruits()
#
# <ipython-input-11-2f8586f1806a> in print_fruits()
#       3     for fruit in list_of_fruits:
#       4         print (fruit.title())
# ----> 5         print_fruits()
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-11-2f8586f1806a> in print_fruits()
#       3     for fruit in list_of_fruits:
#       4         print (fruit.title())
# ----> 5         print_fruits()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
welcome_messages = []
for new_employee in new_employees:
    welcome_messages.append("Hi " + new_employee.title() + ", I'm so glad to be working with you!" )

welcome_messages
# Out:
# ["Hi Jim, I'm so glad to be working with you!",
#  "Hi Tracy, I'm so glad to be working with you!",
#  "Hi Lisa, I'm so glad to be working with you!"]

# %%
item = ['python','SQL','Java']
num_list(item)
# Out:
# python
# SQL
# Java

# %%
list_2 =[1,2,3,4,5,6,7,8,9]
num_list
# Out:
# <function __main__.num_list(i)>

# %%
def addition (n,m):
    result =n +m
    return results

# %%
i = 2
j = 4

# %%
addition (i,j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-224421bb6c51> in <module>
# ----> 1 addition (i,j)
#
# NameError: name 'i' is not defined

# %%
def addition(i, j):
    return i + j

# Example usage
result = addition(5, 3)
print(result)  # Output: 8
# Out:
# 8

# %% [markdown]
# Then a couple of weeks later, a few more employees join, and we want to send messages to them as well.

# %%
new_employees = ['steven', 'jan', 'meryl']

# %% [markdown]
# Well to accomplish welcoming the new employees, we would likely copy our code from above.

# %%
welcome_messages = []
for new_employee in new_employees:
    welcome_messages.append("Hi " + new_employee.title() + ", I'm so glad to be working with you!" )
    
welcome_messages
# Out:
# ["Hi Steven, I'm so glad to be working with you!",
#  "Hi Jan, I'm so glad to be working with you!",
#  "Hi Meryl, I'm so glad to be working with you!"]

# %% [markdown]
# If each time we wanted to reuse code we would have to copy and paste the code and maintain a lot more code than is necessary.  Also, each time we recopied it is another opportunity to make a mistake.  So what if there was a way to write that code just one time, yet be able to execute that code wherever and whenever we want?  Functions allow us to do just that.
#
# Here is that same code wrapped in a function:

# %%
def greet_employees():
    welcome_messages = []
    for new_employee in new_employees:
        welcome_messages.append("Hi " + new_employee.title() + ", I'm so glad to be working with you!" )

    return welcome_messages

# %%
greet_employees()
# Out:
# ["Hi Steven, I'm so glad to be working with you!",
#  "Hi Jan, I'm so glad to be working with you!",
#  "Hi Meryl, I'm so glad to be working with you!"]

# %% [markdown]
# > Make sure to press shift + enter for the two cells above.

# %% [markdown]
# There are two steps to using a function: defining a function and executing a function.  Defining a function happens first, and afterward when we call `greet_employees()` we execute the function.

# %%
new_employees = ['Jan', 'Joe', 'Avi']
greet_employees()
# Out:
# ["Hi Jan, I'm so glad to be working with you!",
#  "Hi Joe, I'm so glad to be working with you!",
#  "Hi Avi, I'm so glad to be working with you!"]

# %% [markdown]
# Ok, let's break down how to define, or declare, a function.  Executing a function is fairly simple, just type the function's name followed by parentheses.

# %%
greet_employees()
# Out:
# ["Hi Jan, I'm so glad to be working with you!",
#  "Hi Joe, I'm so glad to be working with you!",
#  "Hi Avi, I'm so glad to be working with you!"]

# %% [markdown]
# ## Declaring and using functions

# %% [markdown]
# There are two components to declaring a function: the function signature and the function body.

# %%
def name_of_function(): # signature
    words = 'function body' # body
    print(words) # body

# %%
def name_of_function():  # Function signature
    words = 'function body'  # Function body (variable assignment)
    print(words)  # Function body (printing the variable)

# Call the function to execute its body
name_of_function()
# Out:
# function body

# %% [markdown]
# ### Function Signature
#
# The function signature is the first line of the function.  It follows the pattern of `def`, `function name`, `parentheses`, `colon`.
#
# `def name_of_function():`
#
# The `def` is there to tell Python that you are about to declare a function.  The name of the function indicates how to reference and execute the function later.  The colon is to end the function signature and indicate that the body of the function is next.  The parentheses are important as well, and we'll explain their use in a later lesson.
#
# ### Function Body
#
# The body of the function is what the function does.  This is the code that runs each time we execute the function.  We indicate that we are writing the function body by going to the next line and indenting after the colon.  To complete the function body we stop indenting.

# %%
def name_of_function(): 
    words = 'function body' # function body
    print(words) # function body    
# no longer part of the function body

# %% [markdown]
# Let's execute the `name_of_function()` function.

# %%
name_of_function()
# Out:
# function body

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# Did it work?  Kinda.  The lines of our function were run.  But our function did not return anything.  Functions are designed so that everything inside of them stays inside.  So for example, even though we declared the `words` variable, `words` is not available from outside of the function.

# %%
words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-730c51b3e7e0> in <module>
# ----> 1 words
#
# NameError: name 'words' is not defined

# %% [markdown]
# To get something out of the function, we must use the `return` keyword, followed by what we would like to return.  Let's declare another function called `other_function()` that has a body which is exactly the same, but has a return statement.

# %%
def other_function(): # signature
    words = 'returned from inside the function body' # body
    return words

# %%
def other_function():  # Function signature
    words = 'returned from inside the function body'  # Function body (variable assignment)
    return words  # Function body (return the value)

# Call the function and store the returned value
result = other_function()

# Print the returned value
print(result)
# Out:
# returned from inside the function body

# %%
other_function()
# Out:
# 'returned from inside the function body'

# %% [markdown]
# Much better.  So with the return statement we returned the string `'returned from inside the function body'`.

# %% [markdown]
# > We will learn more on what is available from inside and outside of the function, so, don't worry if it feels a little confusing right now.

# %% [markdown]
# ## See it again

# %% [markdown]
# Now let's identify the function signature and function body of our original function, `greet_empoyees()`.

# %%
def greet_employees(): # function signature
    welcome_messages = [] # begin function body
    for new_employee in new_employees:
        welcome_messages.append("Hi " + new_employee.title() + ", I'm so glad to be working with you!" )

    return welcome_messages # return statement

# no longer in function body

# %%
# List of new employees
new_employees = ["alice", "bob", "charlie"]

# Define the function
def greet_employees():
    welcome_messages = []  # Begin function body
    for new_employee in new_employees:
        welcome_messages.append("Hi " + new_employee.title() + ", I'm so glad to be working with you!")

    return welcome_messages  # Return statement

# Call the function and print the result
messages = greet_employees()
print(messages)
# Out:
# ["Hi Alice, I'm so glad to be working with you!", "Hi Bob, I'm so glad to be working with you!", "Hi Charlie, I'm so glad to be working with you!"]

# %% [markdown]
# As you can see, `greet_employees()` has the same components of a function we identified earlier: the function signature, the function body, and the return statement. Each time we call, `greet_employees()`, all of the lines in the body of the function are run.  However, only the return value is accessible from outside of the function.

# %%
greet_employees()
# Out:
# ["Hi Jan, I'm so glad to be working with you!",
#  "Hi Joe, I'm so glad to be working with you!",
#  "Hi Avi, I'm so glad to be working with you!"]

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson we saw how using a function allows us to reuse code without rewriting it.  We saw that to declare a function we first write the function signature, which consists of the `def` keyword, the function name, parentheses, and a colon.  We indicate the body of the function by indenting our code and then writing the code that our function will execute.  To execute the function, we write the function's name followed by parentheses.  Executing the function will run the lines in the body of the function.
